# %%
# Load the library and the dataset
import pandas as pd 
df=pd.read_csv("C://Users//cosmas//Downloads//pima-indians-diabetes.csv")
df
# Out:
#       6  148  72  35    0  33.6  0.627  50  1
# 0     1   85  66  29    0  26.6  0.351  31  0
# 1     8  183  64   0    0  23.3  0.672  32  1
# 2     1   89  66  23   94  28.1  0.167  21  0
# 3     0  137  40  35  168  43.1  2.288  33  1
# 4     5  116  74   0    0  25.6  0.201  30  0
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 762  10  101  76  48  180  32.9  0.171  63  0
# 763   2  122  70  27    0  36.8  0.340  27  0
# 764   5  121  72  23  112  26.2  0.245  30  0
# 765   1  126  60   0    0  30.1  0.349  47  1
# 766   1   93  70  31    0  30.4  0.315  23  0
#
# [767 rows x 9 columns]

# %%
# to lable the column
df.columns= ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
df
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       1    85    66    29     0  26.6  0.351   31      0
# 1       8   183    64     0     0  23.3  0.672   32      1
# 2       1    89    66    23    94  28.1  0.167   21      0
# 3       0   137    40    35   168  43.1  2.288   33      1
# 4       5   116    74     0     0  25.6  0.201   30      0
# ..    ...   ...   ...   ...   ...   ...    ...  ...    ...
# 762    10   101    76    48   180  32.9  0.171   63      0
# 763     2   122    70    27     0  36.8  0.340   27      0
# 764     5   121    72    23   112  26.2  0.245   30      0
# 765     1   126    60     0     0  30.1  0.349   47      1
# 766     1    93    70    31     0  30.4  0.315   23      0
#
# [767 rows x 9 columns]

# %%
# to check the dimension of the data
df.shape
# Out:
# (767, 9)

# %%
# to know the attribute of the datase
df.dtypes
# Out:
# preg       int64
# plas       int64
# pres       int64
# skin       int64
# test       int64
# mass     float64
# pedi     float64
# age        int64
# class      int64
# dtype: object

# %%
# to know the summary of the dataset
df.describe()
# Out:
#              preg        plas        pres        skin        test        mass  \
# count  767.000000  767.000000  767.000000  767.000000  767.000000  767.000000
# mean     3.842243  120.859192   69.101695   20.517601   79.903520   31.990482
# std      3.370877   31.978468   19.368155   15.954059  115.283105    7.889091
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   32.000000   32.000000
# 75%      6.000000  140.000000   80.000000   32.000000  127.500000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age       class
# count  767.000000  767.000000  767.000000
# mean     0.471674   33.219035    0.348110
# std      0.331497   11.752296    0.476682
# min      0.078000   21.000000    0.000000
# 25%      0.243500   24.000000    0.000000
# ...

# %%
#reviewing Class Distribution
count_class = df.groupby('class').size()
count_class
# Out:
# class
# 0    500
# 1    267
# dtype: int64

# %%
# to determine if there are missing data in datset
missing_data=df.isnull()
missing_data
# Out:
#       preg   plas   pres   skin   test   mass   pedi    age  class
# 0    False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...
# 762  False  False  False  False  False  False  False  False  False
# 763  False  False  False  False  False  False  False  False  False
# 764  False  False  False  False  False  False  False  False  False
# 765  False  False  False  False  False  False  False  False  False
# 766  False  False  False  False  False  False  False  False  False
#
# [767 rows x 9 columns]

# %%
#summing up the missing value for each column
missing_count=missing_data.sum()
missing_count
# Out:
# preg     0
# plas     0
# pres     0
# skin     0
# test     0
# mass     0
# pedi     0
# age      0
# class    0
# dtype: int64

# %%
#to determine if there are outlier in the dataset and handle it
#by using IQR(interquartile range)
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
outliers=((df<(Q1-1.5*IQR) | (Q3+1.5*IQR))).amy(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     300         #  (xint or xbool) and (yint or bool)
# --> 301         result = op(x, y)
#     302     except TypeError:
#
# TypeError: ufunc 'bitwise_or' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2864\1376921111.py in <module>
#       4 Q3=df.quantile(0.75)
#       5 IQR=Q3-Q1
# ----> 6 outliers=((df<(Q1-1.5*IQR) | (Q3+1.5*IQR))).amy(axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
# ...

# %%
# to determine and handle the duplicate in the datase
duplicates=df[df.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [preg, plas, pres, skin, test, mass, pedi, age, class]
# Index: []

# %%
#Reviewing Correlation between Attributes
correlations = df.corr(method='pearson')
correlations
# Out:
#            preg      plas      pres      skin      test      mass      pedi  \
# preg   1.000000  0.128846  0.141197 -0.082495 -0.072999  0.017518 -0.033927
# plas   0.128846  1.000000  0.152498  0.056381  0.332383  0.220955  0.136903
# pres   0.141197  0.152498  1.000000  0.207308  0.089098  0.281777  0.041180
# skin  -0.082495  0.056381  0.207308  1.000000  0.437974  0.392553  0.183498
# test  -0.072999  0.332383  0.089098  0.437974  1.000000  0.198111  0.185579
# mass   0.017518  0.220955  0.281777  0.392553  0.198111  1.000000  0.140546
# pedi  -0.033927  0.136903  0.041180  0.183498  0.185579  0.140546  1.000000
# age    0.544018  0.262408  0.239571 -0.115873 -0.040942  0.035911  0.032738
# class  0.221087  0.465856  0.064882  0.073265  0.131984  0.292695  0.173245
#
#             age     class
# preg   0.544018  0.221087
# plas   0.262408  0.465856
# pres   0.239571  0.064882
# skin  -0.115873  0.073265
# test  -0.040942  0.131984
# mass   0.035911  0.292695
# ...

# %%
#reviewing Skew of Attribute Distribution
#from the above output, positive or negative skew can be observed. If the value is closer 
to zero, then it shows less skew
df.skew()
# Out:
# preg     0.903976
# plas     0.176412
# pres    -1.841911
# skin     0.112058
# test     2.270630
# mass    -0.427950
# pedi     1.921190
# age      1.135165
# class    0.638949
# dtype: float64

# %%
# to visualize the data 
#there are two technique which are univariate(histogram,boxplot,density plot),multvariateplot( correlation matrix plot,)
from matplotlib import pyplot
df.hist()
pyplot.show()

# %%
# to draw boxplot
df.plot(kind='box', subplots=True, layout=(3,3), sharex=False,sharey=False)
pyplot.show()

# %%
#preparing the data for ml

# %%
# hypothess testing 
import pandas as pd
iris_data=pd.read_csv("C://Users//cosmas//Desktop//machine learning projec//Iris.csv")
iris_data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2864\1145098647.py in <module>
#       1 # hypothess testing
#       2 import pandas as pd
# ----> 3 iris_data=pd.read_csv("C://Users//cosmas//Desktop//machine learning projec//Iris.csv")
#       4 iris_data
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# hypothess testing
# importing the library and load  the data
import pandas as pd
df=pd.read_csv("C://Users//cosmas//Desktop//machine learning project//Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# TO UNDERSTAND THE DIMENSION OF THE DATA
df.shape
# Out:
# (150, 6)

# %%
#TO KNOW THE DATATYPE OF THE VARIABLE IN THE DATASET
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2864\1906800019.py in <module>
# ----> 1 Species
#
# NameError: name 'Species' is not defined

# %%
#TO GET SUMMARY STATISTICS OF THE DATA
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# T check if we have missing data
missing_data=df.isnull()
missing_data
missing_count=missing_data.sum()
missing_count
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# to see the disribution of the dataset
from matplotlib import pyplot as py
df.hist()
py.show()

# %%
# to see the correlation 
correlations=df.corr(method="pearson")
correlations
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
# one sample t test
# one sample ttes is used to measure(to test hypothesis ) if the mean of the one group is the same as the certain number
from scipy import stats
import seaborn as sns
df=pd.read_csv("C://Users//cosmas//Desktop//machine learning project//Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
## to extract the sepal lengh data from data set
sepal_length_data=df["SepalLengthCm"]
sepal_length_data
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
## to set the null hypothesis population mean 
hypothesized_mean=5.0

# %%
# to perform one sample ttest
t_test,p_value=stats.ttest_1samp(sepal_length_data,hypothesized_mean)
t_test
# Out:
# 12.473257146694761

# %%
p_value
## since the p_value is greter than level of significance(5%) the we fail to reject the null hypothess,
# Out:
# 6.670742299801927e-25

# %%
## to sample t test
# two sample ttest used to compare the means btn two groups 
from scipy import stats
import seaborn as sns
df=pd.read_csv("C://Users//cosmas//Desktop//machine learning project//Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
## to extarct the data 
sepal_length_setosa=df[df['Species']=='Iris-setosa']['SepalLengthCm']
sepal_length_versicolor=df[df['Species']=='Iris-versicolor']['SepalLengthCm']

# %%
## to perfom the two sample ttest 
t_test,p_value=stats.ttest_ind(sepal_length_setosa,sepal_length_versicolor,equal_var=True)
p_value
# Out:
# 8.985235037487079e-18
